# %% [markdown]
# <a href="https://colab.research.google.com/github/hassansai10/Progression/blob/main/ImageFirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from PIL import Image

# %%
Array = np.random.randn(100,100,3)

# %%
Array_pic = Array * 255

# %%
Array_pic
# Out:
# array([[[187,  36,  15],
#         [ 90,  56,  34],
#         [124, 209, 117],
#         ...,
#         [143, 204,   8],
#         [177, 243,  60],
#         [174, 246, 119]],
#
#        [[106,   4,  71],
#         [  5,  94, 157],
#         [ 90, 136,  88],
#         ...,
#         [244,   9,   0],
#         [118, 156,  30],
#         [117, 246, 111]],
#
#        [[ 36,  18, 148],
#         [217, 208, 105],
#         [198,  23, 164],
#         ...,
#         [ 23,  12, 116],
#         [168,  56, 120],
#         [ 58, 253,  97]],
#
#        ...,
#
#        [[ 53,  85,  38],
#         [187,  62, 204],
#         [  9,  37, 248],
#         ...,
#         [ 19,   1, 236],
#         [162,  95,   3],
#         [152, 177, 143]],
#
#        [[ 34, 238, 104],
#         [ 63, 199,  63],
#         [188, 162, 144],
#         ...,
#         [ 68,  38, 181],
#         [187, 223,  91],
#         [ 31, 202, 198]],
#
#        [[184, 126,  59],
#         [108, 168, 183],
#         [206, 229,  36],
# ...

# %%
Array_pic = Array_pic.astype(np.uint8)

# %%
New_image = np.zeros((1920,1080,3),dtype=np.uint8)

# %%
New_image[0,:,0] = 255

# %%
New_image[12:30,:,2] = 255
New_image[12:30,:,0] = 150
New_image[700:1000,:,2] = 150
New_image[700:1000,:,1] = 150
New_image[700:1000,:,0] = 170
New_image[200:300,:,1] = 255
New_image[:,200:400,2] = 170

# %%
image = Image.fromarray(New_image)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1920>

# %%
New_image
