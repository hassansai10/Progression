# %% [markdown]
# ### Importing all the necessary Libraries

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.preprocessing import PolynomialFeatures,StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline as pipeline

# %% [markdown]
# ### Loading The Data

# %%
data = pd.read_csv('survey lung cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %% [markdown]
# ## Replacing Values (Converting Catagorial data to numerical data)

# %%
print (data.dtypes)
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %% [markdown]
# ## Two Objects Class (Convert them)

# %%
data['LUNG_CANCER'] = data['LUNG_CANCER'].replace('YES',1)

# %%
data['LUNG_CANCER'] = data['LUNG_CANCER'].replace('NO',0)

# %%
data['GENDER'] = data['GENDER'].replace('M',1)
data['GENDER'] = data['GENDER'].replace('F',0)

# %% [markdown]
# #### 1=YES 0=NO 1=Male 0=Female

# %%
data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %% [markdown]
# ## Checking Data Types again

# %%
print (data.dtypes)
# Out:
# GENDER                   int64
# AGE                      int64
# SMOKING                  int64
# YELLOW_FINGERS           int64
# ANXIETY                  int64
# PEER_PRESSURE            int64
# CHRONIC DISEASE          int64
# FATIGUE                  int64
# ALLERGY                  int64
# WHEEZING                 int64
# ALCOHOL CONSUMING        int64
# COUGHING                 int64
# SHORTNESS OF BREATH      int64
# SWALLOWING DIFFICULTY    int64
# CHEST PAIN               int64
# LUNG_CANCER              int64
# dtype: object

# %% [markdown]
# ### Conversion Done Checking for Duplicates NULL or is it Required for Over_Sampling

# %%
duplicates = data.duplicated().sum()
duplicates
# Out:
# 33

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
Nulls = data.isnull().sum()

# %%
Nulls
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
Check1 = data[data['LUNG_CANCER'] == 1]
Check0 = data[data['LUNG_CANCER'] == 0]

# %%
Check1
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 5         0   75        1               2        1              1
# 6         1   52        2               1        1              1
# 7         0   51        2               2        2              2
# ..      ...  ...      ...             ...      ...            ...
# 274       1   56        2               1        1              1
# 276       0   62        2               2        2              2
# 278       0   77        2               2        2              2
# 279       0   59        1               2        2              2
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
Check0.count()
# Out:
# GENDER                   38
# AGE                      38
# SMOKING                  38
# YELLOW_FINGERS           38
# ANXIETY                  38
# PEER_PRESSURE            38
# CHRONIC DISEASE          38
# FATIGUE                  38
# ALLERGY                  38
# WHEEZING                 38
# ALCOHOL CONSUMING        38
# COUGHING                 38
# SHORTNESS OF BREATH      38
# SWALLOWING DIFFICULTY    38
# CHEST PAIN               38
# LUNG_CANCER              38
# dtype: int64

# %% [markdown]
# ## 25=0 for lung_cancer when we 25/276 we get 0.09 so 9% of the whole dataset is filled with data of patients that do not have lung cancer so we need over sampling to match both of the densities, or you can say to make both densities of True and Flase Equal or Somewhat Equal

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
X_before_Over_Sampling = data.drop(columns=['LUNG_CANCER'])
Y_before_Over_Sampling = data['LUNG_CANCER']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_before_Over_Sampling,Y_before_Over_Sampling,random_state=42)

# %%
minority_sampling = SMOTE(random_state=42)

# %%
X,Y = minority_sampling.fit_resample(X_train,Y_train)

# %%
print (f'Original Destribution {Counter(Y_train)}')
print (f'Resample Destribution {Counter(Y)}')
# Out:
# Original Destribution Counter({1: 182, 0: 25})
# Resample Destribution Counter({1: 182, 0: 182})

# %%
preprocess = ColumnTransformer(transformers=[('num',StandardScaler(),['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY','PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING','ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH','SWALLOWING DIFFICULTY', 'CHEST PAIN'])])

# %%
Model = pipeline(steps=[('preprocessor',preprocess),('polynomial_features',PolynomialFeatures(degree=1)),('regressor',LogisticRegression(solver='saga',max_iter=1000,random_state=42))])

# %%
GridSearch_params = {'regressor__C':[0.1,1,10,100],'regressor__max_iter':[100,1000,2000],'polynomial_features__degree':[1,2,3],'regressor__solver':['saga','liblinear']}

# %%
GridSearch = GridSearchCV(Model,GridSearch_params,cv=5,scoring='accuracy',n_jobs=-1,verbose=2)
GridSearch.fit(X,Y)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['GENDER',
#                                                                           'AGE',
#                                                                           'SMOKING',
#                                                                           'YELLOW_FINGERS',
#                                                                           'ANXIETY',
#                                                                           'PEER_PRESSURE',
#                                                                           'CHRONIC '
# ...

# %%
print (f'Best Parameter = {GridSearch.best_params_}')
# Out:
# Best Parameter = {'polynomial_features__degree': 1, 'regressor__C': 0.1, 'regressor__max_iter': 100, 'regressor__solver': 'saga'}

# %%
best_model = GridSearch.best_estimator_

# %%
cross_validation = cross_val_score(best_model,X,Y,cv=5,scoring='accuracy',n_jobs=-1,verbose=2)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 28 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %%
print (f'Model Accuracy {cross_validation.mean()}')
# Out:
# Model Accuracy 0.9561263318112634

# %%
predict = best_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
Accuracy = accuracy_score(predict,Y_test)

# %%
print (f'Accuracy = {Accuracy*100:.2f}')
# Out:
# Accuracy = 94.20
